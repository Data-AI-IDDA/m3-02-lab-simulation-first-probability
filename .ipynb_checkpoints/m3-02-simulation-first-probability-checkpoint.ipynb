# %% [markdown]
# # Task 1: Estimate π with Monte Carlo
#
# The idea is simple: inscribe a circle of radius 1 inside a 2×2 square. If you throw random darts uniformly at the square, the fraction that land inside the circle should approximate π/4.
#
# 1. Generate **N = 100,000** random (x, y) points where x and y are each drawn from Uniform(−1, 1).
# 2. Classify each point as "inside" (x² + y² ≤ 1) or "outside" the unit circle.
# 3. Estimate π as `4 × (points inside) / N`.
# 4. Print your estimate alongside the true value of π.
# 5. Create a scatter plot of the first **5,000** points, coloring inside points differently from outside points. Draw the unit circle on top for reference.
#
# **Convergence plot:** Compute the running estimate of π after every 100 points (i.e., at n = 100, 200, 300, …, 100,000). Plot this running estimate with a horizontal line at the true π. Add a title and axis labels.
#
# **Guiding question:** At roughly what sample size does your estimate stabilize within ±0.01 of true π?

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 100000

x = np.random.uniform(-1, 1, N)
y = np.random.uniform(-1, 1, N)

# %%
inside = x**2 + y**2 <= 1

# %%
points_inside = np.sum(inside)

pi_estimate = 4 * points_inside / N

print("Estimated π:", pi_estimate)
print("True π:", np.pi)
print("Error:", abs(pi_estimate - np.pi))
# Out:
# Estimated π: 3.1382
# True π: 3.141592653589793
# Error: 0.0033926535897932375

# %%
n_plot = 5000

theta = np.linspace(0, 2*np.pi, 400)
circle_x = np.cos(theta)
circle_y = np.sin(theta)

plt.figure(figsize=(7,7))

# içəridə olanlar
plt.scatter(x[:n_plot][inside[:n_plot]],
            y[:n_plot][inside[:n_plot]],
            s=8, alpha=0.6, label="Inside")

# çöldə olanlar
plt.scatter(x[:n_plot][~inside[:n_plot]],
            y[:n_plot][~inside[:n_plot]],
            s=8, alpha=0.6, label="Outside")

# dairə
plt.plot(circle_x, circle_y, linewidth=2, label="Circle")

plt.title("Monte Carlo - First 5000 Points")
plt.xlabel("x")
plt.ylabel("y")
plt.axis("equal")
plt.legend()
plt.show()

# %%
cumulative_inside = np.cumsum(inside)

sample_sizes = np.arange(100, N+1, 100)

running_pi = 4 * cumulative_inside[sample_sizes - 1] / sample_sizes

# %%
plt.figure(figsize=(10,6))

plt.plot(sample_sizes, running_pi, label="Estimate")
plt.axhline(np.pi, linestyle="--", label="True π")

plt.title("Convergence of Monte Carlo π")
plt.xlabel("Number of points")
plt.ylabel("π estimate")

plt.legend()
plt.show()

# %%
diff = np.abs(running_pi - np.pi)

within = diff <= 0.01

stable_n = None

for i in range(len(within)):
    if np.all(within[i:]):
        stable_n = sample_sizes[i]
        break

print(stable_n)
# Out:
# 29400

# %% [markdown]
# In my simulation, the estimate of π stabilizes within ±0.01 of the true value at around 13,500 samples. After this point, the estimate remains consistently within this error bound, indicating convergence.

# %% [markdown]
# # Task 2: Coin Flips and Empirical Probability
#
#
# Simulate a series of fair coin flips and observe how the empirical probability of heads converges to 0.5.
#
# 1. Simulate **10,000** fair coin flips (use `np.random.choice([0, 1])` or `np.random.binomial(1, 0.5, size=10000)`).
# 2. Compute the running proportion of heads after each flip (cumulative sum divided by cumulative count).
# 3. Plot the running proportion with a horizontal line at 0.5. Use a log-scaled x-axis so you can see early fluctuations and later stabilization clearly.
# 4. Repeat the experiment **5 times** (5 independent series of 10,000 flips) and overlay all 5 convergence paths on the same plot with different colors.
#
# **Guiding question:** How many flips does it typically take for the running proportion to stay within ±0.01 of 0.5?

# %%
import numpy as np
import matplotlib.pyplot as plt

flips = np.random.binomial(1, 0.5, size=10000)

# %%
flips
# Out:
# array([0, 1, 1, ..., 1, 1, 0], shape=(10000,))

# %%
cum = np.cumsum(flips)
counts = np.arange(1, 10001)
prop = cum / counts

# %%
cum
# Out:
# array([   0,    1,    2, ..., 4963, 4964, 4964], shape=(10000,))

# %%
plt.figure(figsize=(10, 6))
plt.plot(counts, prop, label="Running proportion")
plt.axhline(0.5, linestyle="--", label="True probability = 0.5")

plt.xscale("log")
plt.title("Single Run: Convergence of Heads Proportion")
plt.xlabel("Number of flips (log scale)")
plt.ylabel("Proportion of heads")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))

for i in range(5):
    flips = np.random.binomial(1, 0.5, size=10000)
    cum = np.cumsum(flips)
    counts = np.arange(1, 10001)
    prop = cum / counts

    plt.plot(counts, prop, label=f"Run {i+1}")

plt.axhline(0.5, linestyle="--", label="True probability = 0.5")
plt.xscale("log")
plt.title("5 Runs: Convergence Comparison")
plt.xlabel("Number of flips (log scale)")
plt.ylabel("Proportion of heads")
plt.legend()
plt.show()

# %%
flips = np.random.binomial(1, 0.5, size=10000)

cum = np.cumsum(flips)
counts = np.arange(1, 10001)
prop = cum / counts

diff = np.abs(prop - 0.5)
within = diff <= 0.01

stable_n = None

for i in range(len(within)):
    if np.all(within[i:]):
        stable_n = counts[i]
        break

print("Stabilization point:", stable_n)
# Out:
# Stabilization point: 1755

# %%
stable_points = []

for i in range(5):
    flips = np.random.binomial(1, 0.5, size=10000)
    cum = np.cumsum(flips)
    counts = np.arange(1, 10001)
    prop = cum / counts

    diff = np.abs(prop - 0.5)
    within = diff <= 0.01

    stable_n = None

    for j in range(len(within)):
        if np.all(within[j:]):
            stable_n = counts[j]
            break

    stable_points.append(stable_n)

print("Stabilization points:", stable_points)
# Out:
# Stabilization points: [np.int64(2201), np.int64(4187), np.int64(3520), np.int64(5218), np.int64(3287)]

# %%
valid_points = [x for x in stable_points if x is not None]

if valid_points:
    print("Typical stabilization:", int(np.mean(valid_points)))
else:
    print("No full stabilization within 10,000 flips.")
# Out:
# Typical stabilization: 3682

# %% [markdown]
# * In these simulations, the running proportion of heads converged to within ±0.01 of 0.5 after a few thousand flips, with a typical stabilization point around 2,475 flips.

# %% [markdown]
# # Task 3: Simulating Binomial Experiments
#
# A factory produces widgets with a 3% defect rate. A quality inspector samples 50 widgets per batch.
#
# 1. Simulate **10,000 batches** of 50 widgets each, where each widget has a 3% chance of being defective.
# 2. For each batch, record the number of defective widgets found.
# 3. Plot a histogram of the defect counts across all 10,000 batches. Overlay the theoretical Binomial(n=50, p=0.03) PMF as points connected by a line.
# 4. From your simulation, estimate:
#    - P(0 defects in a batch)
#    - P(3 or more defects in a batch)
#    - The expected number of defects per batch
# 5. Compare each simulation estimate to the theoretical binomial value (use `scipy.stats.binom` or manual calculation).
#
# **Guiding question:** How close are your empirical estimates to the theoretical values? Would 1,000 batches have been enough, or do you need 10,000?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n = 50      # hər batch-də məhsul sayı
p = 0.03    # defect ehtimalı
num_batches = 10000

# hər batch üçün defect sayı
defects = np.random.binomial(n, p, size=num_batches)

# %%
defects
# Out:
# array([1, 3, 1, ..., 0, 3, 2], shape=(10000,))

# %%
plt.figure(figsize=(8,5))
plt.hist(defects, bins=range(0, max(defects)+2), density=True)

plt.title("Histogram of Defects per Batch")
plt.xlabel("Number of defects")
plt.ylabel("Probability")
# Out:
# Text(0, 0.5, 'Probability')

# %%
x = np.arange(0, max(defects)+1)
pmf = binom.pmf(x, n, p)

plt.plot(x, pmf, marker='o')
plt.show()

# %%
p0_emp = np.mean(defects == 0)
p0_emp
# Out:
# np.float64(0.2202)

# %%
p3_emp = np.mean(defects >= 3)
p3_emp
# Out:
# np.float64(0.1849)

# %%
mean_emp = np.mean(defects)
mean_emp
# Out:
# np.float64(1.4857)

# %%
p0_theory = binom.pmf(0, n, p)
p3_theory = 1 - binom.cdf(2, n, p)
mean_theory = n * p

# %%
print("P(0 defects):")
print("Empirical:", p0_emp)
print("Theoretical:", p0_theory)

print("\nP(3 or more defects):")
print("Empirical:", p3_emp)
print("Theoretical:", p3_theory)

print("\nExpected defects:")
print("Empirical:", mean_emp)
print("Theoretical:", mean_theory)
# Out:
# P(0 defects):
# Empirical: 0.2202
# Theoretical: 0.21806537534740766
#
# P(3 or more defects):
# Empirical: 0.1849
# Theoretical: 0.18920192463027863
#
# Expected defects:
# Empirical: 1.4857
# Theoretical: 1.5

# %% [raw]
# The empirical estimates closely match the theoretical binomial probabilities, with minor differences due to sampling variability. While 1,000 batches may provide a reasonable approximation, 10,000 batches result in more stable estimates and better alignment with the theoretical distribution.
