# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import binom

np.random.seed(42)
sns.set_style("whitegrid")

# %% [markdown]
# # Task 1: Estimate π with Monte Carlo
# The idea is simple: inscribe a circle of radius 1 inside a 2×2 square. If you throw random darts uniformly at the square, the fraction that land inside the circle should approximate π/4.
#
# Generate N = 100,000 random (x, y) points where x and y are each drawn from Uniform(−1, 1).
# Classify each point as "inside" (x² + y² ≤ 1) or "outside" the unit circle.
# Estimate π as 4 × (points inside) / N.
# Print your estimate alongside the true value of π.
# Create a scatter plot of the first 5,000 points, coloring inside points differently from outside points. Draw the unit circle on top for reference.
# Convergence plot: Compute the running estimate of π after every 100 points (i.e., at n = 100, 200, 300, …, 100,000). Plot this running estimate with a horizontal line at the true π. Add a title and axis labels.
#
# Guiding question: At roughly what sample size does your estimate stabilize within ±0.01 of true π?

# %%
N = 100_000

# %%
x = np.random.uniform(-1, 1, N)
y = np.random.uniform(-1, 1, N)

# %%
inside = x**2 + y**2 <= 1

# %%
pi = 4*np.sum(inside)/N

# %%
pi
# Out:
# np.float64(3.14412)

# %%
np.pi
# Out:
# 3.141592653589793

# %%
n_plot = 5000
plt.figure(figsize=(6,6))
plt.scatter(x[:n_plot][inside[:n_plot]], y[:n_plot][inside[:n_plot]], s=5, label="Inside")
plt.scatter(x[:n_plot][~inside[:n_plot]], y[:n_plot][~inside[:n_plot]], s=5, label="Outside")

theta = np.linspace(0, 2*np.pi, 200)
plt.plot(np.cos(theta), np.sin(theta), linewidth=2)
plt.title("Monte Carlo π Estimation (First 5000 Points)")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.axis('equal')
plt.show()

# %%
step = 100
running_pi = []

for i in range(step, N+1, step):
    pi_i = 4 * np.sum(inside[:i]) / i
    running_pi.append(pi_i)

steps = np.arange(step, N+1, step)

plt.figure(figsize=(8,5))
plt.plot(steps, running_pi, label="Estimated π")
plt.axhline(np.pi, linestyle='--', label="True π")

plt.title("Convergence of Monte Carlo π Estimate")
plt.xlabel("Number of Points")
plt.ylabel("π Estimate")
plt.legend()
plt.show()

# %%
tolerance = 0.01
stable_n = None

for i, pi_val in zip(steps, running_pi):
    if abs(pi_val - np.pi) <= tolerance:
        stable_n = i
        break

print(f"Estimate first stays within ±0.01 at around n = {stable_n}")
# Out:
# Estimate first stays within ±0.01 at around n = 6400

# %% [markdown]
# # Task 2: Coin Flips and Empirical Probability
# Simulate a series of fair coin flips and observe how the empirical probability of heads converges to 0.5.
#
# Simulate 10,000 fair coin flips (use np.random.choice([0, 1]) or np.random.binomial(1, 0.5, size=10000)).
# Compute the running proportion of heads after each flip (cumulative sum divided by cumulative count).
# Plot the running proportion with a horizontal line at 0.5. Use a log-scaled x-axis so you can see early fluctuations and later stabilization clearly.
# Repeat the experiment 5 times (5 independent series of 10,000 flips) and overlay all 5 convergence paths on the same plot with different colors.
# Guiding question: How many flips does it typically take for the running proportion to stay within ±0.01 of 0.5?

# %%
n= 10000
num_experiments = 5
plt.figure(figsize=(8,5))

for i in range(num_experiments):
    # Simulate coin flips
    coin_flips = np.random.choice([0, 1], size=n)
    
    # Running proportion
    cum_heads = np.cumsum(coin_flips)
    count = np.arange(1, n+1)
    run_proportion = cum_heads / count
    
    # Plot each experiment
    plt.plot(count, run_proportion, label=f'Run {i+1}', alpha=0.7)

# True probability line
plt.axhline(0.5, linestyle='--', label='True Probability (0.5)')

# Log scale
plt.xscale('log')

# Labels and title
plt.xlabel("Number of Flips (log scale)")
plt.ylabel("Proportion of Heads")
plt.title("Convergence of Running Proportion (5 Experiments)")

plt.legend()
plt.show()

# %% [markdown]
# # Task 3: Simulating Binomial Experiments
# A factory produces widgets with a 3% defect rate. A quality inspector samples 50 widgets per batch.
#
# Simulate 10,000 batches of 50 widgets each, where each widget has a 3% chance of being defective.
# For each batch, record the number of defective widgets found.
# Plot a histogram of the defect counts across all 10,000 batches. Overlay the theoretical Binomial(n=50, p=0.03) PMF as points connected by a line.
# From your simulation, estimate:
# P(0 defects in a batch)
# P(3 or more defects in a batch)
# The expected number of defects per batch
# Compare each simulation estimate to the theoretical binomial value (use scipy.stats.binom or manual calculation).
# Guiding question: How close are your empirical estimates to the theoretical values? Would 1,000 batches have been enough, or do you need 10,000?

# %%
from scipy.stats import binom
# Parameters
n_batches = 10000
n = 50
p = 0.03
# Simulate (each batch gives number of defects)
defects = np.random.binomial(n, p, size=n_batches)

# %%
plt.hist(defects, bins=range(0, max(defects)+2), density=True, alpha=0.6, label="Simulation")
plt.xlabel("Number of Defects")
plt.ylabel("Probability")
plt.title("Histogram of Defects per Batch")
plt.legend() 
plt.show()

# %%
x = np.arange(0, max(defects)+1)
pmf = binom.pmf(x, n, p)

plt.plot(x, pmf, 'o-', label="Binomial PMF")

plt.xlabel("Number of Defects")
plt.ylabel("Probability")
plt.title("Defects per Batch")
plt.legend()
plt.show()

# %%
# P(0 defects)
p0_sim = np.mean(defects == 0)
# P(3 or more defects)
p3_sim = np.mean(defects >= 3)
# Expected value
mean_sim = np.mean(defects)
print("Simulation:")
print("P(0 defects):", p0_sim)
print("P(3+ defects):", p3_sim)
print("Mean defects:", mean_sim)
# Out:
# Simulation:
# P(0 defects): 0.2209
# P(3+ defects): 0.1876
# Mean defects: 1.4975

# %%
p0_theory = binom.pmf(0, n, p)
p3_theory = 1 - binom.cdf(2, n, p)
mean_theory = n * p

print("\nTheoretical:")
print("P(0 defects):", p0_theory)
print("P(3+ defects):", p3_theory)
print("Mean defects:", mean_theory)
# Out:
# Theoretical:
# P(0 defects): 0.21806537534740766
# P(3+ defects): 0.18920192463027874
# Mean defects: 1.5

# %% [markdown]
# The simulation results are very close to the theoretical values: P(0 defects) ≈ 0.221 vs 0.218, P(3+ defects) ≈ 0.188 vs 0.189, and the mean defects ≈ 1.498 vs 1.5. The differences are tiny, showing that the simulation approximates the binomial distribution well. Using 1,000 batches could work, but 10,000 batches gives more stable and accurate results.
