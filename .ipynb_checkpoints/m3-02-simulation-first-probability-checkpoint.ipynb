# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)
sns.set_style("whitegrid")

# %% [markdown]
# ## Task 1: Estimate π with Monte Carlo

# %% [markdown]
# #### Step 1: Generate random points

# %%
N = 100_000
x = np.random.uniform(-1, 1, N)
y = np.random.uniform(-1, 1, N)
inside = x**2 + y**2 <= 1
pi_estimate = 4 * np.sum(inside) / N

print(f"Estimated π: {pi_estimate:.5f}")
print(f"True π: {np.pi:.5f}")
# Out:
# Estimated π: 3.14412
# True π: 3.14159

# %% [markdown]
# #### Step 2: Scatter plot of first 5,000 points

# %%
plt.figure(figsize=(6,6))
plt.scatter(x[:5000], y[:5000], c=inside[:5000], cmap='coolwarm', s=10)
circle = plt.Circle((0, 0), 1, color='black', fill=False, linewidth=2)
plt.gca().add_artist(circle)
plt.title("Monte Carlo π: First 5,000 Points")
plt.xlabel("x")
plt.ylabel("y")
plt.axis("equal")
plt.show()

# %% [markdown]
# #### Step 3: Convergence plot

# %%
running_estimate = np.cumsum(inside) / np.arange(1, N+1) * 4
sample_points = np.arange(100, N+1, 100)

plt.figure(figsize=(8,5))
plt.plot(sample_points, running_estimate[99::100])
plt.axhline(np.pi, color='red', linestyle='--', label="True π")
plt.title("Convergence of Monte Carlo π Estimate")
plt.xlabel("Number of Points")
plt.ylabel("Estimated π")
plt.legend()
plt.show()

# %% [markdown]
# #### Guiding question: At roughly what sample size does your estimate stabilize within ±0.01 of true π?
#
# With N = 100,000 points, the estimate usually stabilizes around 10,000–20,000 points.
#
# Before 10,000 points, the running estimate fluctuates more widely; after ~20,000 points, the estimate typically stays within ±0.01 of π.
#
# Observation: Increasing the number of points reduces fluctuations, showing the Law of Large Numbers in action.

# %% [markdown]
# ## Task 2: Coin Flips and Empirical Probability

# %% [markdown]
# #### Step 1: Simulate 10,000 flips

# %%
flips = np.random.binomial(1, 0.5, size=10_000)
running_prop = np.cumsum(flips) / np.arange(1, len(flips)+1)

plt.figure(figsize=(8,5))
plt.plot(running_prop)
plt.axhline(0.5, color='red', linestyle='--')
plt.xscale("log")
plt.title("Convergence of Running Proportion of Heads")
plt.xlabel("Number of Flips (log scale)")
plt.ylabel("Proportion of Heads")
plt.show()

# %% [markdown]
# #### Step 2: Repeat 5 independent series

# %%
plt.figure(figsize=(8,5))
for i in range(5):
    flips = np.random.binomial(1, 0.5, size=10_000)
    running_prop = np.cumsum(flips) / np.arange(1, len(flips)+1)
    plt.plot(running_prop, label=f"Run {i+1}", alpha=0.8)
plt.axhline(0.5, color='black', linestyle='--', label="True 0.5")
plt.xscale("log")
plt.title("Coin Flip Convergence (5 Runs)")
plt.xlabel("Number of Flips (log scale)")
plt.ylabel("Proportion of Heads")
plt.legend()
plt.show()

# %% [markdown]
# #### Guiding question: How many flips does it typically take for the running proportion to stay within ±0.01 of 0.5?
#
# In most simulations, the running proportion of heads stabilizes within ±0.01 of 0.5 after roughly 1,000–2,000 flips.
#
# Early flips show large fluctuations, but as the number of flips increases, the empirical probability converges to the theoretical 0.5.
#
# Observation: Running multiple independent series shows that while each run fluctuates initially, all converge to 0.5 eventually, illustrating the law of large numbers.

# %% [markdown]
# ## Task 3: Simulating Binomial Experiments

# %% [markdown]
# #### Step 1: Simulate 10,000 batches of 50 widgets

# %%
n_batches = 10_000
batch_size = 50
p_defect = 0.03

defects = np.random.binomial(batch_size, p_defect, size=n_batches)

# %% [markdown]
# #### Step 2: Histogram + theoretical PMF

# %%
from scipy.stats import binom

plt.figure(figsize=(8,5))
sns.histplot(defects, bins=range(0, 6), stat="probability", kde=False, color='skyblue', label="Simulated")
x_vals = np.arange(0, 6)
pmf = binom.pmf(x_vals, batch_size, p_defect)
plt.plot(x_vals, pmf, 'o-', color='red', label="Theoretical PMF")
plt.title("Defective Widgets per Batch")
plt.xlabel("Number of Defects")
plt.ylabel("Probability")
plt.legend()
plt.show()

# %% [markdown]
# #### Step 3: Empirical probabilities

# %%
p0_emp = np.mean(defects == 0)
p3plus_emp = np.mean(defects >= 3)
expected_defects = np.mean(defects)

p0_theo = binom.pmf(0, batch_size, p_defect)
p3plus_theo = 1 - binom.cdf(2, batch_size, p_defect)
expected_theo = batch_size * p_defect

print(f"P(0 defects) -> Empirical: {p0_emp:.4f}, Theoretical: {p0_theo:.4f}")
print(f"P(>=3 defects) -> Empirical: {p3plus_emp:.4f}, Theoretical: {p3plus_theo:.4f}")
print(f"Expected defects per batch -> Empirical: {expected_defects:.2f}, Theoretical: {expected_theo:.2f}")
# Out:
# P(0 defects) -> Empirical: 0.2146, Theoretical: 0.2181
# P(>=3 defects) -> Empirical: 0.1926, Theoretical: 0.1892
# Expected defects per batch -> Empirical: 1.51, Theoretical: 1.50

# %% [markdown]
# #### Guiding question: How close are your empirical estimates to the theoretical values? Would 1,000 batches have been enough, or do you need 10,000?
#
# With 10,000 batches:
#
# Empirical P(0 defects) ≈ Theoretical P(0 defects)
#
# Empirical P(≥3 defects) ≈ Theoretical P(≥3 defects)
#
# Empirical expected defects ≈ Theoretical expected defects
#
# With only 1,000 batches, there is more variability in probabilities and expected values; estimates may deviate noticeably from theory.
#
# Observation: 10,000 batches provide very stable and accurate estimates, demonstrating convergence of empirical simulations to theoretical probabilities.
