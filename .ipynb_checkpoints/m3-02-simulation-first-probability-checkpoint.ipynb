# %% [markdown]
# ### Task 1: Estimate π with Monte Carlo

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)
sns.set_style("whitegrid")

# =========================
# Task 1 — Estimate π with Monte Carlo
# =========================

# Generate random points
N = 100_000
x = np.random.uniform(-1, 1, N)
y = np.random.uniform(-1, 1, N)

# Check whether points are inside the unit circle
inside = x**2 + y**2 <= 1

# Estimate pi
pi_estimate = 4 * inside.sum() / N

print(f"Estimated π: {pi_estimate:.5f}")
print(f"True π:      {np.pi:.5f}")
print(f"Error:       {abs(pi_estimate - np.pi):.5f}")

# =========================
# Scatter plot of first 5000 points
# =========================
n_plot = 5000
x_plot = x[:n_plot]
y_plot = y[:n_plot]
inside_plot = inside[:n_plot]

theta = np.linspace(0, 2 * np.pi, 400)
circle_x = np.cos(theta)
circle_y = np.sin(theta)

plt.figure(figsize=(7, 7))
plt.scatter(x_plot[inside_plot], y_plot[inside_plot], s=10, alpha=0.6, label="Inside")
plt.scatter(x_plot[~inside_plot], y_plot[~inside_plot], s=10, alpha=0.6, label="Outside")
plt.plot(circle_x, circle_y, linewidth=2, label="Unit Circle")
plt.title("Monte Carlo Estimation of π (First 5,000 Points)")
plt.xlabel("x")
plt.ylabel("y")
plt.axis("equal")
plt.legend()
plt.show()

# =========================
# Convergence plot
# =========================
step = 100
sample_sizes = np.arange(step, N + 1, step)
running_pi = [4 * inside[:n].sum() / n for n in sample_sizes]

plt.figure(figsize=(10, 5))
plt.plot(sample_sizes, running_pi, label="Running Estimate of π")
plt.axhline(np.pi, linestyle="--", linewidth=2, label="True π")
plt.title("Convergence of Monte Carlo π Estimate")
plt.xlabel("Number of Samples")
plt.ylabel("Estimated π")
plt.legend()
plt.show()

# =========================
# Find first sample size within ±0.01
# =========================
tolerance = 0.01
within_tolerance = np.abs(np.array(running_pi) - np.pi) <= tolerance

first_stable_n = None
for i, ok in enumerate(within_tolerance):
    if ok:
        first_stable_n = sample_sizes[i]
        break

print(f"First sample size within ±0.01 of true π: {first_stable_n}")
# Out:
# Estimated π: 3.14412
# True π:      3.14159
# Error:       0.00253
# First sample size within ±0.01 of true π: 6400

# %% [markdown]
# ### Observation
# The Monte Carlo simulation produced an estimate of π that is very close to the true value, with an error of about 0.0025. The scatter plot clearly shows which points fall inside and outside the unit circle.
#
# The convergence plot shows large fluctuations at small sample sizes, but the estimate becomes much more stable as the sample size increases. In this run, the estimate first came within ±0.01 of the true value at around 6,400 samples, and it stayed much closer to π as the number of samples grew larger.
#
# This is a good example of the Law of Large Numbers: with more random samples, the empirical estimate becomes more reliable.

# %% [markdown]
# ### Task 2: Coin Flips and Empirical Probability

# %%
# =========================
# Task 2 — Coin Flips and Empirical Probability
# =========================

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)
sns.set_style("whitegrid")

n_flips = 10_000
n_experiments = 5
tolerance = 0.01

all_running_props = []

plt.figure(figsize=(10, 5))

for i in range(n_experiments):
    # Simulate fair coin flips: 1 = heads, 0 = tails
    flips = np.random.binomial(1, 0.5, size=n_flips)

    # Running proportion of heads
    running_prop = np.cumsum(flips) / np.arange(1, n_flips + 1)
    all_running_props.append(running_prop)

    # Plot each experiment
    plt.plot(
        np.arange(1, n_flips + 1),
        running_prop,
        linewidth=1.5,
        label=f"Experiment {i+1}"
    )

# Reference line at theoretical probability
plt.axhline(0.5, linestyle="--", linewidth=2, label="True Probability = 0.5")

plt.xscale("log")
plt.xlabel("Number of Flips (log scale)")
plt.ylabel("Running Proportion of Heads")
plt.title("Convergence of Empirical Probability of Heads")
plt.legend()
plt.show()

# =========================
# Find when each experiment STAYS within ±0.01 of 0.5
# =========================

print("Stability results (stays within ±0.01 of 0.5):")

for i, running_prop in enumerate(all_running_props):
    within_tolerance = np.abs(running_prop - 0.5) <= tolerance

    stay_flip = None
    for j in range(len(within_tolerance)):
        if np.all(within_tolerance[j:]):
            stay_flip = j + 1   # +1 because flip count starts at 1
            break

    if stay_flip is not None:
        print(f"Experiment {i+1}: stays within ±0.01 starting from flip {stay_flip}")
    else:
        print(f"Experiment {i+1}: does not stay within ±0.01 for the rest of the 10,000 flips")

# =========================
# Final running proportions
# =========================

print("\nFinal running proportions:")
for i, running_prop in enumerate(all_running_props):
    print(f"Experiment {i+1}: {running_prop[-1]:.4f}")
# Out:
# Stability results (stays within ±0.01 of 0.5):
# Experiment 1: stays within ±0.01 starting from flip 2283
# Experiment 2: stays within ±0.01 starting from flip 1671
# Experiment 3: stays within ±0.01 starting from flip 7616
# Experiment 4: stays within ±0.01 starting from flip 1218
# Experiment 5: stays within ±0.01 starting from flip 1824
#
# Final running proportions:
# Experiment 1: 0.4924
# Experiment 2: 0.5064
# Experiment 3: 0.5022
# Experiment 4: 0.5000
# Experiment 5: 0.4937

# %% [markdown]
# ### Observation
# The running proportion of heads fluctuates heavily at the beginning because small samples are highly affected by randomness. Although some experiments may temporarily fall within the ±0.01 range early on, they do not remain stable.
#
# As the number of flips increases, the estimates become more stable and stay close to 0.5. In these simulations, most experiments stabilize within the ±0.01 range after roughly 1,000 to 3,000 flips, although some may take longer.
#
# This demonstrates the Law of Large Numbers: as the sample size increases, the empirical probability becomes more reliable and converges to the true probability.

# %% [markdown]
# ### Task 3: Simulating Binomial Experiments

# %%
# =========================
# Task 3 — Binomial Simulation
# =========================

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

np.random.seed(42)
sns.set_style("whitegrid")

# Parameters
n_batches = 10_000
n_widgets = 50
p_defect = 0.03

# =========================
# Simulate batches
# =========================
# Each batch: number of defects out of 50 trials
defects = np.random.binomial(n_widgets, p_defect, size=n_batches)

# =========================
# Histogram of simulation
# =========================
plt.figure(figsize=(10, 5))

# Histogram (normalized)
sns.histplot(defects, bins=range(0, max(defects)+2), stat="probability", alpha=0.6, label="Simulation")

# =========================
# Theoretical Binomial PMF
# =========================
x = np.arange(0, n_widgets + 1)
binom_dist = stats.binom(n_widgets, p_defect)
pmf = binom_dist.pmf(x)

plt.plot(x, pmf, "o-", label="Theoretical Binomial PMF")

plt.xlabel("Number of Defects per Batch")
plt.ylabel("Probability")
plt.title("Binomial Simulation vs Theoretical Distribution")
plt.legend()
plt.show()

# =========================
# Empirical estimates
# =========================
p_0_defects_sim = np.mean(defects == 0)
p_3plus_sim = np.mean(defects >= 3)
expected_sim = np.mean(defects)

# =========================
# Theoretical values
# =========================
p_0_defects_theory = binom_dist.pmf(0)
p_3plus_theory = 1 - binom_dist.cdf(2)
expected_theory = binom_dist.mean()

# =========================
# Print comparison
# =========================
print("=== Simulation vs Theoretical ===\n")

print(f"P(0 defects):")
print(f"  Simulation:  {p_0_defects_sim:.4f}")
print(f"  Theoretical: {p_0_defects_theory:.4f}\n")

print(f"P(3 or more defects):")
print(f"  Simulation:  {p_3plus_sim:.4f}")
print(f"  Theoretical: {p_3plus_theory:.4f}\n")

print(f"Expected defects per batch:")
print(f"  Simulation:  {expected_sim:.4f}")
print(f"  Theoretical: {expected_theory:.4f}")
# Out:
# === Simulation vs Theoretical ===
#
# P(0 defects):
#   Simulation:  0.2224
#   Theoretical: 0.2181
#
# P(3 or more defects):
#   Simulation:  0.1828
#   Theoretical: 0.1892
#
# Expected defects per batch:
#   Simulation:  1.4751
#   Theoretical: 1.5000

# %% [markdown]
# ### Observation
#
# The simulated results closely match the theoretical Binomial distribution. The histogram and the theoretical PMF have very similar shapes, which shows that the simulation is accurate.
#
# The estimated probabilities for P(0 defects), P(3 or more defects), and the expected number of defects are all very close to the theoretical values. The small differences are caused by randomness in the simulation.
#
# This shows that with a large number of samples (10,000 batches), simulation can approximate theoretical probabilities very well. It also confirms that the Binomial distribution is a good model for this type of problem.
