# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)
sns.set_style("whitegrid")

# %%
# task1

# %%
N = 100_000

x = np.random.uniform(-1, 1, N)
y = np.random.uniform(-1, 1, N)

inside = x**2 + y**2 <= 1

pi_estimate = 4 * np.sum(inside) / N

print("Estimated π:", pi_estimate)
print("True π:", np.pi)

# %%
# Monte Carlo π estimate is within ±0.02 of true π (with 100,000 samples):
# Estimated π: 3.14696
# True π: 3.141592653589793

# %%
subset = 5000

plt.figure(figsize=(6,6))
plt.scatter(x[:subset][inside[:subset]], y[:subset][inside[:subset]], s=1, label="Inside")
plt.scatter(x[:subset][~inside[:subset]], y[:subset][~inside[:subset]], s=1, label="Outside")

circle = plt.Circle((0,0), 1, color='red', fill=False)
plt.gca().add_patch(circle)

plt.legend()
plt.title("Monte Carlo π Estimation (First 5000 points)")
plt.xlabel("x")
plt.ylabel("y")
plt.axis("equal")
plt.show()

# %%
running_estimates = []

for i in range(100, N+1, 100):
    est = 4 * np.sum(inside[:i]) / i
    running_estimates.append(est)

steps = np.arange(100, N+1, 100)

plt.figure(figsize=(8,5))
plt.plot(steps, running_estimates, label="Estimate")
plt.axhline(np.pi, linestyle="--", label="True π")

plt.title("Convergence of π Estimate")
plt.xlabel("Number of samples")
plt.ylabel("π estimate")
plt.legend()
plt.show()

# %%
# The estimate stabilizes within ±0.01 of π at around 20,000–30,000 samples.

# %%
# task2

# %%
flips = np.random.binomial(1, 0.5, size=10000)

running_heads = np.cumsum(flips)
running_prob = running_heads / np.arange(1, 10001)

plt.figure(figsize=(8,5))
plt.plot(running_prob)
plt.axhline(0.5, linestyle="--")

plt.xscale("log")
plt.title("Running Probability of Heads")
plt.xlabel("Number of flips (log scale)")
plt.ylabel("P(Heads)")
plt.show()

# %%
#I repetead the experiment 5 times.The running proportion stabilizes within ±0.01 of 0.5 after about 2,000–5,000 flips.

# %%
# task3

# %%
n_batches = 10000
n = 50
p = 0.03
batches = np.random.binomial(n,p,size=n_batches)
batches

# %%
plt.figure(figsize=(8,5))
sns.histplot(batches,bins=range(0,max(batches)+2),stat="probability",discrete=True)
plt.title("Distribution of Defects per Batch")
plt.xlabel("Number of defects")
plt.ylabel("Probability")
plt.show()

# %%
from scipy.stats import binom

x_vals = np.arange(0,max(batches)+1)
pmf = binom.pmf(x_vals,n,p)

plt.figure(figsize=(8,5))
sns.histplot(batches,bins=range(0,max(batches)+2),stat="probability",alpha=0.6)
plt.plot(x_vals, pmf, 'o-', label="Theoretical")
plt.legend()
plt.title("Simulation vs Binomial PMF")
plt.show()

# %%
p0_sim = np.mean(batches == 0)
p3plus_sim = np.mean(batches >= 3)
expected_sim = np.mean(batches)

print("Simulation:")
print("P(0 defects):", p0_sim)
print("P(≥3 defects):", p3plus_sim)
print("Expected defects:", expected_sim)

# %%
p0_theory = binom.pmf(0, n, p)
p3plus_theory = 1 - binom.cdf(2, n, p)
expected_theory = n * p

print("\nTheoretical:")
print("P(0 defects):", p0_theory)
print("P(≥3 defects):", p3plus_theory)
print("Expected defects:", expected_theory)

# %%
# The empirical results are very close to theoretical values. With 10,000 batches, estimates are highly accurate. Using only 1,000 batches would still work but with more variance.
